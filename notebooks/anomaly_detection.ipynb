# %% [markdown]
# ## 多変量ガウス分布モデル
#
# 多変量ガウス分布は、$k$ 次元の連続値ベクトル $x \in \mathbb{R}^k$ に対して、次の確率密度関数を持つ
# $$
# p(x; \mu, \Sigma) = \frac{1}{(2\pi)^{k/2} |\Sigma|^{1/2}} \exp \left( -\frac{1}{2} (x - \mu)^T \Sigma^{-1} (x - \mu) \right)
# $$
#
# - $\mu \in \mathbb{R}^k$：平均ベクトル（各特徴量の中心）
# - $\Sigma \in \mathbb{R}^{k \times k}$：共分散行列（特徴量間の分散や相関）
#
# ---
#
# ## 正常データからのパラメータ推定
#
# 正常データ $\{ x^{(i)} \}_{i=1}^m$ を用いて、平均ベクトル $\mu$ と分散共分散行列 $\Sigma$ を推定する
#
# $$
# \mu = \frac{1}{m} \sum_{i=1}^{m} x^{(i)}
# $$
#
# $$
# \Sigma = \frac{1}{m} \sum_{i=1}^{m} (x^{(i)} - \mu)(x^{(i)} - \mu)^T
# $$
#
# ---
#
# ## 新しいデータの異常スコア算出
#
# 未知のデータ $x$ に対して、正規分布からの異常度を以下の確率で評価する
#
# $$
# p(x) = p(x; \mu, \Sigma)
# $$
#
# この確率値が小さいほど、「通常とは異なる異常なデータ」である
#
# ---
#
# ## 閾値 $\epsilon$ による異常判定
#
# 確率密度 $p(x)$ がある閾値 $\epsilon$ 未満であれば異常、それ以外は正常
#
# $$
# \hat{y} =
# \begin{cases}
# 1 & \text{if } p(x) < \epsilon \quad \text{(異常)} \\
# 0 & \text{if } p(x) \ge \epsilon \quad \text{(正常)}
# \end{cases}
# $$
#
# ---
#
# ## 閾値の最適化と性能評価（F1スコア）
#
# 検証データにおいて、様々な $\epsilon$ に対して予測を行い、F1スコアが最大になる $\epsilon$ を選ぶ
#
# 適合率（Precision）：
#
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# 再現率（Recall）：
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# F1スコア：異常を見逃さず、誤検知が少ない指標
#
# $$
# F_1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
#
# - $TP$：異常を正しく検出した件数（True Positive）
# - $FP$：正常を誤って異常と予測した件数（False Positive）
# - $FN$：異常を見逃した件数（False Negative）

# %%
#ライブラリのインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.covariance import EllipticEnvelope
from sklearn.metrics import f1_score

# %%
# データ読み込み
train_df = pd.read_csv("../datasets/tr_server_data.csv")     # 学習用 (正常のみの特徴量)
val_df = pd.read_csv("../datasets/cv_server_data.csv")       # 検証用 (特徴量のみ)
gt_df = pd.read_csv("../datasets/gt_server_data.csv")        # 検証用ラベル (正常=0, 異常=1)

X_train = train_df.values
X_val = val_df.values
y_val = gt_df.values.flatten()       # 1次元に変換

print(f"Train shape: {X_train.shape}, Validation shape: {X_val.shape}, Label shape: {y_val.shape}")

#  平均・分散推定
def estimate_gaussian(X):
    mu = np.mean(X, axis=0)
    var = np.var(X, axis=0)
    return mu, var

mu, var = estimate_gaussian(X_train) #(2,)[1.0, 2.0]

# 多変量ガウス確率の計算(サンプルが中心の平均 muに近いほど、多変量ガウス確率密度は高くなる)
def multivariate_gaussian(X, mu, var):
    k = len(mu)
    if var.ndim == 1:
        var = np.diag(var) #[[1.0, 0.0], [0.0, 2.0]]
    X = X - mu
    inv_var = np.linalg.inv(var) #[[1.0, 0.0], [0.0, 0.5]]
    exp_term = np.sum((np.dot(X, inv_var)) * X, axis=1) #(306,)
    coeff = 1 / ( (2 * np.pi)**(k/2) * np.linalg.det(var)**0.5 )
    return coeff * np.exp(-0.5 * exp_term) #(306,)

p_val = multivariate_gaussian(X_val, mu, var)

# 閾値探索関数
def select_threshold(y_val, p_val):#(306,)
    best_epsilon = 0 # 閾値（これより小さい確率は異常と判定）
    best_F1 = 0
    step = (max(p_val) - min(p_val)) / 1000

    for eps in np.arange(min(p_val), max(p_val), step):
        pred = p_val < eps # ex:) eps = 0.06
        # p_val = [0.10, 0.20, 0.05, 0.01, 0.15]
        # pred = [False, False, True, True, False]
        tp = np.sum((pred == 1) & (y_val == 1))  # 正しく異常と判定
        fp = np.sum((pred == 1) & (y_val == 0))  # 正常なのに異常と誤判定
        fn = np.sum((pred == 0) & (y_val == 1))  # 異常なのに見逃し

        if tp + fp == 0 or tp + fn == 0:
            continue
        prec = tp / (tp + fp)
        rec = tp / (tp + fn)
        F1 = 2 * prec * rec / (prec + rec)
        if F1 > best_F1:
            best_F1 = F1
            best_epsilon = eps

    return best_epsilon, best_F1

epsilon, F1 = select_threshold(y_val, p_val)

print(f"Best epsilon: {epsilon}")
print(f"Best F1 score: {F1}")



# 可視化関数
def visualize_fit(X, mu, vars):
    plt.figure(figsize=(8,6))
    plt.scatter(X[:, 0], X[:, 1], marker='x', c='b', label='Data points')
    # 訓練データの確率計算と異常検出
    p_train = multivariate_gaussian(X_train, mu, var)
    outliers = p_train < epsilon
    x = np.linspace(np.min(X[:, 0]), np.max(X[:, 0]), 100)
    y = np.linspace(np.min(X[:, 1]), np.max(X[:, 1]), 100)
    X1, X2 = np.meshgrid(x, y)
    Z = multivariate_gaussian(np.c_[X1.ravel(), X2.ravel()], mu, var)
    Z = Z.reshape(X1.shape)

    # 確率等高線
    plt.contour(X1, X2, Z, levels=10, cmap='jet')

    # 異常と判定された点
    p = multivariate_gaussian(X, mu, var)
    outliers = X[p < epsilon]
    plt.scatter(outliers[:, 0], outliers[:, 1], c='r', marker='o', edgecolors='k', s=60, label='Outliers')
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.title("Gaussian Fit Contour")
    plt.legend()
    plt.show()

# 呼び出し
visualize_fit(X_val, mu, var)
# Out:
# Train shape: (306, 2), Validation shape: (306, 2), Label shape: (306,)
# Best epsilon: 8.971080231004169e-05
# Best F1 score: 0.8750000000000001

# %%
# sikit
model = EllipticEnvelope(contamination=np.mean(y_val))
model.fit(X_train)

# 検証データに対するスコア（異常度に近いもの）
scores = model.score_samples(X_val)  # 高いほど正常に近いスコア

# 閾値探索関数
def select_threshold(y_val, scores):
    best_epsilon = None
    best_F1 = 0
    step = (max(scores) - min(scores)) / 1000
    for eps in np.arange(min(scores), max(scores), step):
        # score_samples はスコアが高いほど正常なので、閾値より小さいものを異常と判定
        pred = scores < eps
        tp = np.sum((pred == 1) & (y_val == 1))
        fp = np.sum((pred == 1) & (y_val == 0))
        fn = np.sum((pred == 0) & (y_val == 1))

        if tp + fp == 0 or tp + fn == 0:
            continue
        prec = tp / (tp + fp)
        rec = tp / (tp + fn)
        F1 = 2 * prec * rec / (prec + rec)
        if F1 > best_F1:
            best_F1 = F1
            best_epsilon = eps
    return best_epsilon, best_F1

epsilon, best_f1 = select_threshold(y_val, scores)
print(f"Best epsilon: {epsilon}")
print(f"Best F1 score : {best_f1:.4f}")


y_pred = (scores < epsilon).astype(int)

# 可視化関数
def visualize_elliptic_envelope(X_train, X_val, y_pred):
    plt.figure(figsize=(8,6))
    plt.scatter(X_val[y_pred == 0, 0], X_val[y_pred == 0, 1], label="Normal", c="b", marker='o')
    plt.scatter(X_val[y_pred == 1, 0], X_val[y_pred == 1, 1], label="Anomaly", c="r", marker='x')
    plt.title("Elliptic Envelope - Anomaly Detection")
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.legend()
    plt.grid(False)
    plt.show()

visualize_elliptic_envelope(X_train, X_val, y_pred)
# Out:
# Best epsilon: -52.62384251390927
# Best F1 score (with threshold tuning): 0.8750
# Original F1 score (no threshold tuning): 0.7368
